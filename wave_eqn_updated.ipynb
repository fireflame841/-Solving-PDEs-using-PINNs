# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim import lr_scheduler
from tqdm.notebook import tqdm
from scipy.stats import bernoulli

# %%
class Model(nn.Module):
    def __init__(self, input_dim=2, hidden_dim=128):
        super(Model, self).__init__()
        self.fc1 = nn.Linear(in_features=2, out_features=hidden_dim)
        self.fc2 = nn.Linear(in_features=hidden_dim, out_features=hidden_dim)
        self.fc3 = nn.Linear(in_features=hidden_dim, out_features=hidden_dim)
        self.fc4 = nn.Linear(in_features=hidden_dim, out_features=hidden_dim)
        self.fc5 = nn.Linear(in_features=hidden_dim, out_features=1)

    def forward(self, x,t):
        x = torch.concat([x,t], axis=1)
        x = F.tanh(self.fc1(x))
        x = F.tanh(self.fc2(x))
        x = F.tanh(self.fc3(x))
        x = F.tanh(self.fc4(x))
        x = self.fc5(x)
        return x

# %%
train_dataset = torch.load('uxt_data_with_noise_Train.pt')
test_dataset = torch.load('uxt_data_without_noise_Test.pt')

u_train, x_train, t_train = train_dataset.T
x_train = x_train.unsqueeze(1)
t_train = t_train.unsqueeze(1)

u_test, x_test, t_test = test_dataset.T
x_test = x_test.unsqueeze(1)
t_test = t_test.unsqueeze(1)

# %%
def compute_grad(u, x):
    return_value =  torch.autograd.grad(u, x, create_graph=True, grad_outputs=torch.ones_like(u), allow_unused=True)[0]
    if return_value == None:
        return_value = torch.zeros_like(u)
    return return_value


def get_Laplacian(u,x):
    du_dx = compute_grad(u, x)
    d2u_dx2 = compute_grad(du_dx[:,0], x)[:,0]
    return d2u_dx2

def get_Error(u_pred, u_true):
    den = torch.linalg.norm(u_pred-u_true)
    nom = torch.linalg.norm(u_true)
    return float(den/nom)

# %%
num_epochs = 10000
learning_rate = 0.001
sch_Step_Size = 1000
sch_Gamma = 0.9
#Batch Size -> Use Full Batch
#The number of pts
num_GE = 5000 #Govern_Eqn
num_BC = 1000 #Boundary_Condition
num_IC = 1000 #Initial_Condition

#terminal time and the boundary of x
T = 2*torch.pi
x_min = -1.
x_max = 1.

# %%
model = Model()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
scheduler = lr_scheduler.StepLR(optimizer, step_size=sch_Step_Size, gamma=sch_Gamma)

logs = {'Train_Loss':[], 'Train_Err':[], 'Test_Err':[]}
for e in tqdm(range(1, num_epochs+1)):
    model.train()
    ### 01. Data Generation (Collocation Points) ###
    #points for GE
    x_GE = (T/2)*torch.rand(size=(num_GE,)) #(num_GE,)
    t_GE = T*torch.rand(size=(num_GE,)) #(num_GE,)
    x_GE = x_GE.unsqueeze(1)
    t_GE = t_GE.unsqueeze(1)
    # xt_GE = get_concat(x_GE, t_GE) #(num_GE, 2)

    #points for IC
    x_IC = (T/2)*torch.rand(size=(num_IC,))
    t_IC = torch.zeros_like(x_IC).float()
    x_IC = x_IC.unsqueeze(1)
    t_IC = t_IC.unsqueeze(1)
    # xt_IC = get_concat(x_IC, t_IC) #(num_IC, 2)

    #points for BC
    x_BC = (T/2)*torch.tensor(bernoulli.rvs(size=num_BC, p=0.5)).float()
    t_BC = T*torch.rand(size=(num_BC,))
    x_BC = x_BC.unsqueeze(1)
    t_BC = t_BC.unsqueeze(1)
    # xt_BC = get_concat(x_BC, t_BC) #of shape (num_BC, 2)


    ### 02. Update Parameters ###
    optimizer.zero_grad()

    #Loss_GE
    x_GE.requires_grad = True
    t_GE.requires_grad = True
    u_pred_GE = model(x_GE,t_GE).squeeze() #Forward; of shape (num_GE, )
    utt = get_Laplacian(u_pred_GE, t_GE).squeeze()
    uxx = get_Laplacian(u_pred_GE, x_GE).squeeze()
    Loss_GE = ((utt - uxx)**2).mean()

    #Loss_IC
    u_pred_IC = model(x_IC,t_IC).squeeze() #Forward; of shape (num_IC, )
    u_IC = torch.sin(x_IC).squeeze()
    Loss_IC = ((u_pred_IC - u_IC)**2).mean()

    #Loss_BC
    u_pred_BC = model(x_BC,t_BC).squeeze() #Forward; of shape (num_BC, )
    Loss_BC = (u_pred_BC**2).mean() #According to BC, u_pred_BC should be zero

    #Loss_NN
    u_prediction = model(x_train,t_train).squeeze() #Forward; of shape (num_train, )
    Loss_NN = ((u_prediction - u_train)**2).mean()

    #Loss_Total -> Update
    Loss_Total = Loss_GE + Loss_IC + Loss_BC + Loss_NN
    Loss_Total.backward()
    optimizer.step() #Backpropagation -> Update Parameters

    #Train_Err
    Train_Err = get_Error(u_prediction, u_train)

    #Log
    Loss_eth = float(Loss_Total.item())
    logs['Train_Loss'].append(Loss_eth)
    logs['Train_Err'].append(Train_Err)

    scheduler.step()

    #Evaluate Test Error
    model.eval()
    with torch.no_grad():
        u_prediction_test = model(x_test,t_test).squeeze() #Forward; of shape (num_test, )
        Test_Err = get_Error(u_prediction_test, u_test)
        logs['Test_Err'].append(Test_Err)

    #print()
    if e % 10 == 0:
        print('{}th Epoch Train Loss {:.5f}'.format(e, Loss_eth))
        print('{}th Epoch Train Error {:.3f}%'.format(e, 100*Train_Err))
        print('{}th Epoch Test Error {:.3f}%'.format(e, 100*Test_Err))
        print()
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# 10th Epoch Train Loss 0.52396
# 10th Epoch Train Error 65.623%
# 10th Epoch Test Error 84.285%
#
# 20th Epoch Train Loss 0.36314
# 20th Epoch Train Error 51.351%
# 20th Epoch Test Error 83.876%
#
# 30th Epoch Train Loss 0.33536
# 30th Epoch Train Error 43.268%
# 30th Epoch Test Error 95.176%
#
# 40th Epoch Train Loss 0.28532
# 40th Epoch Train Error 39.935%
# 40th Epoch Test Error 88.175%
#
# 50th Epoch Train Loss 0.20933
# 50th Epoch Train Error 34.742%
# 50th Epoch Test Error 87.432%
#
# 60th Epoch Train Loss 0.14321
# 60th Epoch Train Error 23.905%
# 60th Epoch Test Error 88.026%
#
# 70th Epoch Train Loss 0.10550
# 70th Epoch Train Error 16.338%
# 70th Epoch Test Error 84.158%
#
# 80th Epoch Train Loss 0.08204
# 80th Epoch Train Error 13.417%
# 80th Epoch Test Error 82.263%
#
# 90th Epoch Train Loss 0.07005
# 90th Epoch Train Error 11.434%
# 90th Epoch Test Error 82.632%
#
# 100th Epoch Train Loss 0.06622
# 100th Epoch Train Error 10.604%
# 100th Epoch Test Error 76.998%
#
# 110th Epoch Train Loss 0.06347
# 110th Epoch Train Error 9.953%
# 110th Epoch Test Error 75.247%
#
# 120th Epoch Train Loss 0.06069
# 120th Epoch Train Error 8.968%
# 120th Epoch Test Error 74.265%
#
# 130th Epoch Train Loss 0.05488
# 130th Epoch Train Error 8.670%
# 130th Epoch Test Error 73.861%
#
# 140th Epoch Train Loss 0.05464
# 140th Epoch Train Error 8.333%
# 140th Epoch Test Error 71.774%
#
# 150th Epoch Train Loss 0.05475
# 150th Epoch Train Error 7.730%
# 150th Epoch Test Error 68.985%
#
# 160th Epoch Train Loss 0.05403
# 160th Epoch Train Error 7.599%
# 160th Epoch Test Error 68.819%
#
# 170th Epoch Train Loss 0.05045
# 170th Epoch Train Error 8.963%
# 170th Epoch Test Error 68.901%
#
# 180th Epoch Train Loss 0.04667
# 180th Epoch Train Error 9.957%
# 180th Epoch Test Error 65.411%
#
# 190th Epoch Train Loss 0.04513
# 190th Epoch Train Error 9.287%
# 190th Epoch Test Error 64.510%
#
# 200th Epoch Train Loss 0.04663
# 200th Epoch Train Error 6.251%
# 200th Epoch Test Error 59.741%
#
# 210th Epoch Train Loss 0.04595
# 210th Epoch Train Error 11.795%
# 210th Epoch Test Error 62.927%
#
# 220th Epoch Train Loss 0.04235
# 220th Epoch Train Error 10.094%
# 220th Epoch Test Error 62.254%
#
# 230th Epoch Train Loss 0.03866
# 230th Epoch Train Error 7.445%
# 230th Epoch Test Error 60.179%
#
# 240th Epoch Train Loss 0.04372
# 240th Epoch Train Error 5.905%
# 240th Epoch Test Error 55.446%
#
# 250th Epoch Train Loss 0.03454
# 250th Epoch Train Error 7.781%
# 250th Epoch Test Error 57.190%
#
# 260th Epoch Train Loss 0.03476
# 260th Epoch Train Error 5.683%
# 260th Epoch Test Error 54.771%
#
# 270th Epoch Train Loss 0.03448
# 270th Epoch Train Error 8.011%
# 270th Epoch Test Error 54.005%
#
# 280th Epoch Train Loss 0.03292
# 280th Epoch Train Error 5.041%
# 280th Epoch Test Error 51.763%
#
# 290th Epoch Train Loss 0.07152
# 290th Epoch Train Error 11.680%
# 290th Epoch Test Error 47.694%
#
# 300th Epoch Train Loss 0.04343
# 300th Epoch Train Error 6.129%
# 300th Epoch Test Error 54.069%
#
# 310th Epoch Train Loss 0.03079
# 310th Epoch Train Error 6.577%
# 310th Epoch Test Error 49.521%
#
# 320th Epoch Train Loss 0.03389
# 320th Epoch Train Error 9.042%
# 320th Epoch Test Error 55.003%
#
# 330th Epoch Train Loss 0.02898
# 330th Epoch Train Error 4.867%
# 330th Epoch Test Error 49.878%
#
# 340th Epoch Train Loss 0.02801
# 340th Epoch Train Error 5.984%
# 340th Epoch Test Error 47.607%
#
# 350th Epoch Train Loss 0.03271
# 350th Epoch Train Error 4.614%
# 350th Epoch Test Error 48.587%
#
# 360th Epoch Train Loss 0.02808
# 360th Epoch Train Error 4.091%
# 360th Epoch Test Error 44.122%
#
# 370th Epoch Train Loss 0.02608
# 370th Epoch Train Error 7.269%
# 370th Epoch Test Error 47.382%
#
# 380th Epoch Train Loss 0.02890
# 380th Epoch Train Error 8.872%
# 380th Epoch Test Error 47.531%
#
# 390th Epoch Train Loss 0.02298
# 390th Epoch Train Error 5.046%
# 390th Epoch Test Error 42.729%
#
# 400th Epoch Train Loss 0.08121
# 400th Epoch Train Error 13.719%
# 400th Epoch Test Error 41.766%
#
# 410th Epoch Train Loss 0.03636
# 410th Epoch Train Error 12.171%
# 410th Epoch Test Error 50.828%
#
# 420th Epoch Train Loss 0.03047
# 420th Epoch Train Error 4.766%
# 420th Epoch Test Error 44.607%
#
# 430th Epoch Train Loss 0.02707
# 430th Epoch Train Error 8.965%
# 430th Epoch Test Error 42.512%
#
# 440th Epoch Train Loss 0.02433
# 440th Epoch Train Error 3.669%
# 440th Epoch Test Error 43.235%
#
# 450th Epoch Train Loss 0.02178
# 450th Epoch Train Error 5.736%
# 450th Epoch Test Error 45.543%
#
# 460th Epoch Train Loss 0.02181
# 460th Epoch Train Error 4.081%
# 460th Epoch Test Error 39.390%
#
# 470th Epoch Train Loss 0.02056
# 470th Epoch Train Error 4.946%
# 470th Epoch Test Error 42.200%
#
# 480th Epoch Train Loss 0.02550
# 480th Epoch Train Error 3.933%
# 480th Epoch Test Error 38.022%
#
# 490th Epoch Train Loss 0.03100
# 490th Epoch Train Error 10.920%
# 490th Epoch Test Error 45.940%
#
# 500th Epoch Train Loss 0.03084
# 500th Epoch Train Error 10.653%
# 500th Epoch Test Error 43.068%
#
# 510th Epoch Train Loss 0.01967
# 510th Epoch Train Error 4.449%
# 510th Epoch Test Error 38.353%
#
# 520th Epoch Train Loss 0.02008
# 520th Epoch Train Error 3.500%
# 520th Epoch Test Error 38.361%
#
# 530th Epoch Train Loss 0.02553
# 530th Epoch Train Error 7.905%
# 530th Epoch Test Error 36.134%
#
# 540th Epoch Train Loss 0.01912
# 540th Epoch Train Error 3.297%
# 540th Epoch Test Error 36.800%
#
# 550th Epoch Train Loss 0.01997
# 550th Epoch Train Error 5.943%
# 550th Epoch Test Error 40.005%
#
# 560th Epoch Train Loss 0.05152
# 560th Epoch Train Error 15.406%
# 560th Epoch Test Error 41.775%
#
# 570th Epoch Train Loss 0.02338
# 570th Epoch Train Error 7.666%
# 570th Epoch Test Error 41.431%
#
# 580th Epoch Train Loss 0.02052
# 580th Epoch Train Error 6.639%
# 580th Epoch Test Error 36.735%
#
# 590th Epoch Train Loss 0.01861
# 590th Epoch Train Error 5.699%
# 590th Epoch Test Error 35.950%
#
# 600th Epoch Train Loss 0.01884
# 600th Epoch Train Error 3.044%
# 600th Epoch Test Error 34.804%
#
# 610th Epoch Train Loss 0.03080
# 610th Epoch Train Error 6.703%
# 610th Epoch Test Error 33.542%
#
# 620th Epoch Train Loss 0.01615
# 620th Epoch Train Error 4.993%
# 620th Epoch Test Error 35.113%
#
# 630th Epoch Train Loss 0.01555
# 630th Epoch Train Error 3.991%
# 630th Epoch Test Error 36.344%
#
# 640th Epoch Train Loss 0.02078
# 640th Epoch Train Error 7.709%
# 640th Epoch Test Error 34.320%
#
# 650th Epoch Train Loss 0.01664
# 650th Epoch Train Error 3.164%
# 650th Epoch Test Error 33.746%
#
# 660th Epoch Train Loss 0.01553
# 660th Epoch Train Error 2.862%
# 660th Epoch Test Error 34.236%
#
# 670th Epoch Train Loss 0.08816
# 670th Epoch Train Error 16.669%
# 670th Epoch Test Error 34.365%
#
# 680th Epoch Train Loss 0.02013
# 680th Epoch Train Error 4.898%
# 680th Epoch Test Error 42.965%
#
# 690th Epoch Train Loss 0.02209
# 690th Epoch Train Error 4.382%
# 690th Epoch Test Error 37.007%
#
# 700th Epoch Train Loss 0.01591
# 700th Epoch Train Error 4.518%
# 700th Epoch Test Error 35.686%
#
# 710th Epoch Train Loss 0.01588
# 710th Epoch Train Error 4.784%
# 710th Epoch Test Error 33.794%
#
# 720th Epoch Train Loss 0.01536
# 720th Epoch Train Error 3.644%
# 720th Epoch Test Error 33.838%
#
# 730th Epoch Train Loss 0.01474
# 730th Epoch Train Error 2.987%
# 730th Epoch Test Error 33.489%
#
# 740th Epoch Train Loss 0.01371
# 740th Epoch Train Error 3.102%
# 740th Epoch Test Error 31.219%
#
# 750th Epoch Train Loss 0.01362
# 750th Epoch Train Error 3.181%
# 750th Epoch Test Error 31.486%
#
# 760th Epoch Train Loss 0.01415
# 760th Epoch Train Error 2.900%
# 760th Epoch Test Error 31.708%
#
# 770th Epoch Train Loss 0.01942
# 770th Epoch Train Error 6.038%
# 770th Epoch Test Error 34.604%
#
# 780th Epoch Train Loss 0.03113
# 780th Epoch Train Error 11.314%
# 780th Epoch Test Error 34.843%
#
# 790th Epoch Train Loss 0.01838
# 790th Epoch Train Error 4.410%
# 790th Epoch Test Error 30.986%
#
# 800th Epoch Train Loss 0.01665
# 800th Epoch Train Error 3.776%
# 800th Epoch Test Error 30.446%
#
# 810th Epoch Train Loss 0.01365
# 810th Epoch Train Error 4.699%
# 810th Epoch Test Error 30.907%
#
# 820th Epoch Train Loss 0.01491
# 820th Epoch Train Error 3.812%
# 820th Epoch Test Error 28.955%
#
# 830th Epoch Train Loss 0.03100
# 830th Epoch Train Error 7.554%
# 830th Epoch Test Error 30.217%
#
# 840th Epoch Train Loss 0.01572
# 840th Epoch Train Error 3.892%
# 840th Epoch Test Error 31.073%
#
# 850th Epoch Train Loss 0.01354
# 850th Epoch Train Error 3.122%
# 850th Epoch Test Error 32.326%
#
# 860th Epoch Train Loss 0.01517
# 860th Epoch Train Error 3.310%
# 860th Epoch Test Error 29.062%
#
# 870th Epoch Train Loss 0.01470
# 870th Epoch Train Error 5.147%
# 870th Epoch Test Error 31.999%
#
# 880th Epoch Train Loss 0.01393
# 880th Epoch Train Error 3.200%
# 880th Epoch Test Error 27.875%
#
# 890th Epoch Train Loss 0.01154
# 890th Epoch Train Error 3.338%
# 890th Epoch Test Error 29.112%
#
# 900th Epoch Train Loss 0.02860
# 900th Epoch Train Error 10.528%
# 900th Epoch Test Error 36.196%
#
# 910th Epoch Train Loss 0.01526
# 910th Epoch Train Error 4.217%
# 910th Epoch Test Error 34.407%
#
# 920th Epoch Train Loss 0.01422
# 920th Epoch Train Error 4.931%
# 920th Epoch Test Error 31.657%
#
# 930th Epoch Train Loss 0.01248
# 930th Epoch Train Error 3.123%
# 930th Epoch Test Error 32.697%
#
# 940th Epoch Train Loss 0.01223
# 940th Epoch Train Error 3.794%
# 940th Epoch Test Error 29.444%
#
# 950th Epoch Train Loss 0.01216
# 950th Epoch Train Error 2.924%
# 950th Epoch Test Error 28.234%
#
# 960th Epoch Train Loss 0.01173
# 960th Epoch Train Error 3.015%
# 960th Epoch Test Error 29.882%
#
# 970th Epoch Train Loss 0.01327
# 970th Epoch Train Error 4.619%
# 970th Epoch Test Error 27.918%
#
# 980th Epoch Train Loss 0.01248
# 980th Epoch Train Error 2.731%
# 980th Epoch Test Error 29.292%
#
# 990th Epoch Train Loss 0.01081
# 990th Epoch Train Error 2.854%
# 990th Epoch Test Error 27.132%
#
# 1000th Epoch Train Loss 0.01097
# 1000th Epoch Train Error 2.907%
# 1000th Epoch Test Error 26.221%
#
# 1010th Epoch Train Loss 0.01124
# 1010th Epoch Train Error 3.883%
# 1010th Epoch Test Error 26.092%
#
# 1020th Epoch Train Loss 0.01466
# 1020th Epoch Train Error 4.991%
# 1020th Epoch Test Error 28.259%
#
# 1030th Epoch Train Loss 0.01044
# 1030th Epoch Train Error 2.971%
# 1030th Epoch Test Error 26.676%
#
# 1040th Epoch Train Loss 0.01083
# 1040th Epoch Train Error 3.651%
# 1040th Epoch Test Error 27.107%
#
# 1050th Epoch Train Loss 0.02101
# 1050th Epoch Train Error 6.775%
# 1050th Epoch Test Error 26.310%
#
# 1060th Epoch Train Loss 0.01875
# 1060th Epoch Train Error 8.292%
# 1060th Epoch Test Error 29.596%
#
# 1070th Epoch Train Loss 0.01154
# 1070th Epoch Train Error 4.654%
# 1070th Epoch Test Error 28.127%
#
# 1080th Epoch Train Loss 0.01229
# 1080th Epoch Train Error 5.009%
# 1080th Epoch Test Error 27.588%
#
# 1090th Epoch Train Loss 0.01147
# 1090th Epoch Train Error 3.646%
# 1090th Epoch Test Error 27.407%
#
# 1100th Epoch Train Loss 0.01221
# 1100th Epoch Train Error 3.300%
# 1100th Epoch Test Error 25.846%
#
# 1110th Epoch Train Loss 0.01386
# 1110th Epoch Train Error 5.673%
# 1110th Epoch Test Error 26.473%
#
# 1120th Epoch Train Loss 0.01307
# 1120th Epoch Train Error 4.337%
# 1120th Epoch Test Error 25.305%
#
# 1130th Epoch Train Loss 0.01251
# 1130th Epoch Train Error 3.490%
# 1130th Epoch Test Error 25.529%
#
# 1140th Epoch Train Loss 0.01252
# 1140th Epoch Train Error 3.610%
# 1140th Epoch Test Error 26.127%
#
# 1150th Epoch Train Loss 0.01484
# 1150th Epoch Train Error 6.757%
# 1150th Epoch Test Error 28.457%
#
# 1160th Epoch Train Loss 0.01098
# 1160th Epoch Train Error 2.896%
# 1160th Epoch Test Error 25.898%
#
# 1170th Epoch Train Loss 0.01210
# 1170th Epoch Train Error 4.992%
# 1170th Epoch Test Error 26.159%
#
# 1180th Epoch Train Loss 0.00995
# 1180th Epoch Train Error 3.224%
# 1180th Epoch Test Error 26.829%
#
# 1190th Epoch Train Loss 0.01240
# 1190th Epoch Train Error 4.865%
# 1190th Epoch Test Error 26.811%
#
# 1200th Epoch Train Loss 0.01012
# 1200th Epoch Train Error 4.294%
# 1200th Epoch Test Error 26.972%
#
# 1210th Epoch Train Loss 0.01554
# 1210th Epoch Train Error 4.924%
# 1210th Epoch Test Error 28.187%
#
# 1220th Epoch Train Loss 0.01152
# 1220th Epoch Train Error 4.937%
# 1220th Epoch Test Error 27.982%
#
# 1230th Epoch Train Loss 0.00953
# 1230th Epoch Train Error 3.449%
# 1230th Epoch Test Error 25.593%
#
# 1240th Epoch Train Loss 0.00956
# 1240th Epoch Train Error 2.712%
# 1240th Epoch Test Error 24.882%
#
# 1250th Epoch Train Loss 0.01050
# 1250th Epoch Train Error 2.981%
# 1250th Epoch Test Error 24.671%
#
# 1260th Epoch Train Loss 0.00934
# 1260th Epoch Train Error 2.883%
# 1260th Epoch Test Error 24.450%
#
# 1270th Epoch Train Loss 0.00928
# 1270th Epoch Train Error 3.716%
# 1270th Epoch Test Error 25.720%
#
# 1280th Epoch Train Loss 0.00873
# 1280th Epoch Train Error 2.837%
# 1280th Epoch Test Error 24.603%
#
# 1290th Epoch Train Loss 0.00837
# 1290th Epoch Train Error 2.703%
# 1290th Epoch Test Error 24.747%
#
# 1300th Epoch Train Loss 0.01611
# 1300th Epoch Train Error 6.021%
# 1300th Epoch Test Error 23.920%
#
# 1310th Epoch Train Loss 0.01313
# 1310th Epoch Train Error 5.708%
# 1310th Epoch Test Error 29.814%
#
# 1320th Epoch Train Loss 0.00898
# 1320th Epoch Train Error 3.483%
# 1320th Epoch Test Error 26.252%
#
# 1330th Epoch Train Loss 0.00883
# 1330th Epoch Train Error 2.680%
# 1330th Epoch Test Error 24.744%
#
# 1340th Epoch Train Loss 0.00797
# 1340th Epoch Train Error 2.641%
# 1340th Epoch Test Error 24.476%
#
# 1350th Epoch Train Loss 0.00870
# 1350th Epoch Train Error 3.801%
# 1350th Epoch Test Error 24.449%
#
# 1360th Epoch Train Loss 0.00866
# 1360th Epoch Train Error 2.966%
# 1360th Epoch Test Error 24.633%
#
# 1370th Epoch Train Loss 0.02849
# 1370th Epoch Train Error 11.046%
# 1370th Epoch Test Error 28.971%
#
# 1380th Epoch Train Loss 0.00850
# 1380th Epoch Train Error 2.767%
# 1380th Epoch Test Error 26.638%
#
# 1390th Epoch Train Loss 0.00950
# 1390th Epoch Train Error 2.983%
# 1390th Epoch Test Error 24.576%
#
# 1400th Epoch Train Loss 0.00832
# 1400th Epoch Train Error 2.670%
# 1400th Epoch Test Error 23.907%
#
# 1410th Epoch Train Loss 0.00822
# 1410th Epoch Train Error 2.659%
# 1410th Epoch Test Error 23.373%
#
# 1420th Epoch Train Loss 0.01075
# 1420th Epoch Train Error 4.181%
# 1420th Epoch Test Error 22.807%
#
# 1430th Epoch Train Loss 0.01165
# 1430th Epoch Train Error 5.547%
# 1430th Epoch Test Error 25.114%
#
# 1440th Epoch Train Loss 0.00756
# 1440th Epoch Train Error 3.329%
# 1440th Epoch Test Error 24.484%
#
# 1450th Epoch Train Loss 0.00957
# 1450th Epoch Train Error 2.596%
# 1450th Epoch Test Error 24.706%
#
# 1460th Epoch Train Loss 0.00861
# 1460th Epoch Train Error 2.791%
# 1460th Epoch Test Error 23.039%
#
# 1470th Epoch Train Loss 0.00900
# 1470th Epoch Train Error 3.976%
# 1470th Epoch Test Error 23.645%
#
# 1480th Epoch Train Loss 0.00979
# 1480th Epoch Train Error 3.010%
# 1480th Epoch Test Error 25.535%
#
# 1490th Epoch Train Loss 0.03461
# 1490th Epoch Train Error 12.497%
# 1490th Epoch Test Error 27.885%
#
# 1500th Epoch Train Loss 0.01370
# 1500th Epoch Train Error 6.391%
# 1500th Epoch Test Error 27.623%
#
# 1510th Epoch Train Loss 0.00921
# 1510th Epoch Train Error 4.185%
# 1510th Epoch Test Error 24.954%
#
# 1520th Epoch Train Loss 0.01123
# 1520th Epoch Train Error 5.304%
# 1520th Epoch Test Error 24.012%
#
# 1530th Epoch Train Loss 0.01119
# 1530th Epoch Train Error 5.438%
# 1530th Epoch Test Error 24.818%
#
# 1540th Epoch Train Loss 0.00883
# 1540th Epoch Train Error 3.621%
# 1540th Epoch Test Error 24.302%
#
# 1550th Epoch Train Loss 0.01166
# 1550th Epoch Train Error 3.758%
# 1550th Epoch Test Error 22.803%
#
# 1560th Epoch Train Loss 0.01170
# 1560th Epoch Train Error 5.826%
# 1560th Epoch Test Error 23.398%
#
# 1570th Epoch Train Loss 0.00910
# 1570th Epoch Train Error 3.084%
# 1570th Epoch Test Error 23.436%
#
# 1580th Epoch Train Loss 0.01068
# 1580th Epoch Train Error 4.311%
# 1580th Epoch Test Error 22.998%
#
# 1590th Epoch Train Loss 0.01425
# 1590th Epoch Train Error 6.855%
# 1590th Epoch Test Error 23.989%
#
# 1600th Epoch Train Loss 0.00775
# 1600th Epoch Train Error 2.544%
# 1600th Epoch Test Error 22.894%
#
# 1610th Epoch Train Loss 0.01071
# 1610th Epoch Train Error 4.364%
# 1610th Epoch Test Error 21.837%
#
# 1620th Epoch Train Loss 0.00812
# 1620th Epoch Train Error 3.357%
# 1620th Epoch Test Error 23.288%
#
# 1630th Epoch Train Loss 0.01367
# 1630th Epoch Train Error 5.756%
# 1630th Epoch Test Error 21.818%
#
# 1640th Epoch Train Loss 0.00899
# 1640th Epoch Train Error 3.798%
# 1640th Epoch Test Error 23.125%
#
# 1650th Epoch Train Loss 0.00716
# 1650th Epoch Train Error 2.559%
# 1650th Epoch Test Error 22.052%
#
# 1660th Epoch Train Loss 0.01016
# 1660th Epoch Train Error 4.772%
# 1660th Epoch Test Error 24.618%
#
# 1670th Epoch Train Loss 0.00750
# 1670th Epoch Train Error 3.526%
# 1670th Epoch Test Error 23.018%
#
# 1680th Epoch Train Loss 0.00829
# 1680th Epoch Train Error 2.877%
# 1680th Epoch Test Error 22.926%
#
# 1690th Epoch Train Loss 0.01098
# 1690th Epoch Train Error 4.390%
# 1690th Epoch Test Error 21.957%
#
# 1700th Epoch Train Loss 0.00931
# 1700th Epoch Train Error 2.987%
# 1700th Epoch Test Error 22.051%
#
# 1710th Epoch Train Loss 0.00876
# 1710th Epoch Train Error 3.016%
# 1710th Epoch Test Error 21.547%
#
# 1720th Epoch Train Loss 0.00692
# 1720th Epoch Train Error 2.501%
# 1720th Epoch Test Error 21.777%
#
# 1730th Epoch Train Loss 0.00704
# 1730th Epoch Train Error 2.567%
# 1730th Epoch Test Error 21.445%
#
# 1740th Epoch Train Loss 0.00698
# 1740th Epoch Train Error 2.751%
# 1740th Epoch Test Error 21.502%
#
# 1750th Epoch Train Loss 0.00776
# 1750th Epoch Train Error 3.901%
# 1750th Epoch Test Error 22.003%
#
# 1760th Epoch Train Loss 0.00746
# 1760th Epoch Train Error 3.217%
# 1760th Epoch Test Error 21.279%
#
# 1770th Epoch Train Loss 0.00890
# 1770th Epoch Train Error 4.045%
# 1770th Epoch Test Error 22.057%
#
# 1780th Epoch Train Loss 0.00655
# 1780th Epoch Train Error 2.627%
# 1780th Epoch Test Error 20.655%
#
# 1790th Epoch Train Loss 0.01034
# 1790th Epoch Train Error 4.604%
# 1790th Epoch Test Error 20.278%
#
# 1800th Epoch Train Loss 0.00852
# 1800th Epoch Train Error 3.515%
# 1800th Epoch Test Error 24.110%
#
# 1810th Epoch Train Loss 0.00683
# 1810th Epoch Train Error 2.784%
# 1810th Epoch Test Error 23.417%
#
# 1820th Epoch Train Loss 0.00776
# 1820th Epoch Train Error 3.376%
# 1820th Epoch Test Error 22.005%
#
# 1830th Epoch Train Loss 0.00668
# 1830th Epoch Train Error 2.392%
# 1830th Epoch Test Error 22.073%
#
# 1840th Epoch Train Loss 0.00699
# 1840th Epoch Train Error 2.884%
# 1840th Epoch Test Error 20.740%
#
# 1850th Epoch Train Loss 0.00817
# 1850th Epoch Train Error 3.507%
# 1850th Epoch Test Error 20.174%
#
# 1860th Epoch Train Loss 0.00656
# 1860th Epoch Train Error 2.573%
# 1860th Epoch Test Error 20.448%
#
# 1870th Epoch Train Loss 0.00664
# 1870th Epoch Train Error 2.550%
# 1870th Epoch Test Error 20.616%
#
# 1880th Epoch Train Loss 0.00639
# 1880th Epoch Train Error 2.719%
# 1880th Epoch Test Error 19.791%
#
# 1890th Epoch Train Loss 0.01620
# 1890th Epoch Train Error 6.769%
# 1890th Epoch Test Error 19.882%
#
# 1900th Epoch Train Loss 0.00635
# 1900th Epoch Train Error 2.660%
# 1900th Epoch Test Error 20.504%
#
# 1910th Epoch Train Loss 0.00739
# 1910th Epoch Train Error 3.479%
# 1910th Epoch Test Error 21.418%
#
# 1920th Epoch Train Loss 0.00654
# 1920th Epoch Train Error 2.616%
# 1920th Epoch Test Error 20.259%
#
# 1930th Epoch Train Loss 0.00742
# 1930th Epoch Train Error 3.460%
# 1930th Epoch Test Error 19.399%
#
# 1940th Epoch Train Loss 0.00638
# 1940th Epoch Train Error 2.383%
# 1940th Epoch Test Error 20.726%
#
# 1950th Epoch Train Loss 0.02418
# 1950th Epoch Train Error 9.992%
# 1950th Epoch Test Error 26.310%
#
# 1960th Epoch Train Loss 0.00963
# 1960th Epoch Train Error 4.217%
# 1960th Epoch Test Error 20.229%
#
# 1970th Epoch Train Loss 0.00797
# 1970th Epoch Train Error 3.423%
# 1970th Epoch Test Error 20.035%
#
# 1980th Epoch Train Loss 0.00617
# 1980th Epoch Train Error 2.945%
# 1980th Epoch Test Error 19.806%
#
# 1990th Epoch Train Loss 0.00765
# 1990th Epoch Train Error 2.880%
# 1990th Epoch Test Error 21.316%
#
# 2000th Epoch Train Loss 0.00666
# 2000th Epoch Train Error 2.667%
# 2000th Epoch Test Error 19.084%
#
# 2010th Epoch Train Loss 0.00560
# 2010th Epoch Train Error 2.504%
# 2010th Epoch Test Error 18.898%
#
# 2020th Epoch Train Loss 0.00622
# 2020th Epoch Train Error 2.559%
# 2020th Epoch Test Error 18.826%
#
# 2030th Epoch Train Loss 0.00599
# 2030th Epoch Train Error 2.617%
# 2030th Epoch Test Error 18.576%
#
# 2040th Epoch Train Loss 0.00542
# 2040th Epoch Train Error 2.492%
# 2040th Epoch Test Error 19.002%
#
# 2050th Epoch Train Loss 0.00604
# 2050th Epoch Train Error 2.443%
# 2050th Epoch Test Error 18.597%
#
# 2060th Epoch Train Loss 0.00573
# 2060th Epoch Train Error 2.332%
# 2060th Epoch Test Error 18.542%
#
# 2070th Epoch Train Loss 0.00686
# 2070th Epoch Train Error 2.520%
# 2070th Epoch Test Error 18.953%
#
# 2080th Epoch Train Loss 0.00720
# 2080th Epoch Train Error 2.982%
# 2080th Epoch Test Error 19.273%
#
# 2090th Epoch Train Loss 0.00700
# 2090th Epoch Train Error 3.773%
# 2090th Epoch Test Error 20.378%
#
# 2100th Epoch Train Loss 0.00592
# 2100th Epoch Train Error 2.476%
# 2100th Epoch Test Error 18.299%
#
# 2110th Epoch Train Loss 0.00609
# 2110th Epoch Train Error 2.801%
# 2110th Epoch Test Error 18.885%
#
# 2120th Epoch Train Loss 0.00610
# 2120th Epoch Train Error 2.676%
# 2120th Epoch Test Error 17.908%
#
# 2130th Epoch Train Loss 0.00845
# 2130th Epoch Train Error 4.650%
# 2130th Epoch Test Error 17.534%
#
# 2140th Epoch Train Loss 0.00840
# 2140th Epoch Train Error 3.540%
# 2140th Epoch Test Error 20.154%
#
# 2150th Epoch Train Loss 0.00534
# 2150th Epoch Train Error 2.539%
# 2150th Epoch Test Error 18.362%
#
# 2160th Epoch Train Loss 0.00596
# 2160th Epoch Train Error 2.545%
# 2160th Epoch Test Error 17.548%
#
# 2170th Epoch Train Loss 0.00564
# 2170th Epoch Train Error 2.848%
# 2170th Epoch Test Error 17.604%
#
# 2180th Epoch Train Loss 0.00781
# 2180th Epoch Train Error 4.145%
# 2180th Epoch Test Error 17.067%
#
# 2190th Epoch Train Loss 0.00611
# 2190th Epoch Train Error 3.129%
# 2190th Epoch Test Error 17.431%
#
# 2200th Epoch Train Loss 0.00546
# 2200th Epoch Train Error 2.463%
# 2200th Epoch Test Error 17.928%
#
# 2210th Epoch Train Loss 0.00619
# 2210th Epoch Train Error 3.293%
# 2210th Epoch Test Error 17.309%
#
# 2220th Epoch Train Loss 0.00574
# 2220th Epoch Train Error 2.830%
# 2220th Epoch Test Error 18.025%
#
# 2230th Epoch Train Loss 0.01854
# 2230th Epoch Train Error 8.911%
# 2230th Epoch Test Error 20.985%
#
# 2240th Epoch Train Loss 0.00516
# 2240th Epoch Train Error 2.338%
# 2240th Epoch Test Error 19.194%
#
# 2250th Epoch Train Loss 0.00570
# 2250th Epoch Train Error 2.834%
# 2250th Epoch Test Error 17.571%
#
# 2260th Epoch Train Loss 0.00517
# 2260th Epoch Train Error 2.417%
# 2260th Epoch Test Error 17.157%
#
# 2270th Epoch Train Loss 0.00452
# 2270th Epoch Train Error 2.370%
# 2270th Epoch Test Error 17.316%
#
# 2280th Epoch Train Loss 0.00495
# 2280th Epoch Train Error 2.375%
# 2280th Epoch Test Error 17.048%
#
# 2290th Epoch Train Loss 0.00463
# 2290th Epoch Train Error 2.233%
# 2290th Epoch Test Error 16.732%
#
# 2300th Epoch Train Loss 0.00659
# 2300th Epoch Train Error 3.822%
# 2300th Epoch Test Error 17.439%
#
# 2310th Epoch Train Loss 0.00475
# 2310th Epoch Train Error 2.837%
# 2310th Epoch Test Error 17.206%
#
# 2320th Epoch Train Loss 0.00651
# 2320th Epoch Train Error 3.554%
# 2320th Epoch Test Error 18.165%
#
# 2330th Epoch Train Loss 0.01524
# 2330th Epoch Train Error 7.556%
# 2330th Epoch Test Error 19.790%
#
# 2340th Epoch Train Loss 0.00701
# 2340th Epoch Train Error 3.518%
# 2340th Epoch Test Error 17.010%
#
# 2350th Epoch Train Loss 0.00480
# 2350th Epoch Train Error 2.366%
# 2350th Epoch Test Error 16.357%
#
# 2360th Epoch Train Loss 0.00523
# 2360th Epoch Train Error 2.161%
# 2360th Epoch Test Error 16.890%
#
# 2370th Epoch Train Loss 0.00524
# 2370th Epoch Train Error 2.446%
# 2370th Epoch Test Error 16.662%
#
# 2380th Epoch Train Loss 0.00486
# 2380th Epoch Train Error 2.374%
# 2380th Epoch Test Error 16.002%
#
# 2390th Epoch Train Loss 0.00455
# 2390th Epoch Train Error 2.221%
# 2390th Epoch Test Error 15.925%
#
# 2400th Epoch Train Loss 0.01694
# 2400th Epoch Train Error 8.013%
# 2400th Epoch Test Error 16.829%
#
# 2410th Epoch Train Loss 0.00679
# 2410th Epoch Train Error 4.291%
# 2410th Epoch Test Error 16.853%
#
# 2420th Epoch Train Loss 0.00497
# 2420th Epoch Train Error 2.218%
# 2420th Epoch Test Error 15.981%
#
# 2430th Epoch Train Loss 0.00501
# 2430th Epoch Train Error 2.416%
# 2430th Epoch Test Error 15.862%
#
# 2440th Epoch Train Loss 0.00457
# 2440th Epoch Train Error 2.838%
# 2440th Epoch Test Error 16.500%
#
# 2450th Epoch Train Loss 0.00417
# 2450th Epoch Train Error 2.281%
# 2450th Epoch Test Error 15.561%
#
# 2460th Epoch Train Loss 0.00545
# 2460th Epoch Train Error 2.151%
# 2460th Epoch Test Error 16.364%
#
# 2470th Epoch Train Loss 0.00636
# 2470th Epoch Train Error 3.793%
# 2470th Epoch Test Error 16.905%
#
# 2480th Epoch Train Loss 0.00417
# 2480th Epoch Train Error 2.308%
# 2480th Epoch Test Error 15.664%
#
# 2490th Epoch Train Loss 0.00440
# 2490th Epoch Train Error 2.278%
# 2490th Epoch Test Error 15.153%
#
# 2500th Epoch Train Loss 0.00656
# 2500th Epoch Train Error 3.826%
# 2500th Epoch Test Error 16.840%
#
# 2510th Epoch Train Loss 0.00629
# 2510th Epoch Train Error 3.465%
# 2510th Epoch Test Error 15.934%
#
# 2520th Epoch Train Loss 0.00587
# 2520th Epoch Train Error 3.510%
# 2520th Epoch Test Error 16.119%
#
# 2530th Epoch Train Loss 0.00440
# 2530th Epoch Train Error 2.733%
# 2530th Epoch Test Error 15.575%
#
# 2540th Epoch Train Loss 0.00442
# 2540th Epoch Train Error 2.350%
# 2540th Epoch Test Error 16.030%
#
# 2550th Epoch Train Loss 0.00573
# 2550th Epoch Train Error 2.540%
# 2550th Epoch Test Error 15.362%
#
# 2560th Epoch Train Loss 0.00645
# 2560th Epoch Train Error 3.576%
# 2560th Epoch Test Error 16.725%
#
# 2570th Epoch Train Loss 0.00450
# 2570th Epoch Train Error 2.492%
# 2570th Epoch Test Error 15.048%
#
# 2580th Epoch Train Loss 0.00420
# 2580th Epoch Train Error 2.419%
# 2580th Epoch Test Error 14.488%
#
# 2590th Epoch Train Loss 0.00873
# 2590th Epoch Train Error 5.332%
# 2590th Epoch Test Error 14.367%
#
# 2600th Epoch Train Loss 0.00770
# 2600th Epoch Train Error 4.845%
# 2600th Epoch Test Error 16.481%
#
# 2610th Epoch Train Loss 0.00531
# 2610th Epoch Train Error 2.815%
# 2610th Epoch Test Error 14.517%
#
# 2620th Epoch Train Loss 0.00502
# 2620th Epoch Train Error 2.964%
# 2620th Epoch Test Error 15.391%
#
# 2630th Epoch Train Loss 0.00568
# 2630th Epoch Train Error 3.762%
# 2630th Epoch Test Error 14.184%
#
# 2640th Epoch Train Loss 0.00447
# 2640th Epoch Train Error 2.280%
# 2640th Epoch Test Error 14.353%
#
# 2650th Epoch Train Loss 0.00445
# 2650th Epoch Train Error 2.628%
# 2650th Epoch Test Error 14.180%
#
# 2660th Epoch Train Loss 0.00693
# 2660th Epoch Train Error 4.375%
# 2660th Epoch Test Error 15.228%
#
# 2670th Epoch Train Loss 0.00431
# 2670th Epoch Train Error 2.801%
# 2670th Epoch Test Error 13.938%
#
# 2680th Epoch Train Loss 0.00436
# 2680th Epoch Train Error 2.526%
# 2680th Epoch Test Error 13.800%
#
# 2690th Epoch Train Loss 0.00424
# 2690th Epoch Train Error 2.603%
# 2690th Epoch Test Error 14.770%
#
# 2700th Epoch Train Loss 0.00727
# 2700th Epoch Train Error 4.746%
# 2700th Epoch Test Error 15.615%
#
# 2710th Epoch Train Loss 0.00383
# 2710th Epoch Train Error 2.185%
# 2710th Epoch Test Error 13.687%
#
# 2720th Epoch Train Loss 0.00373
# 2720th Epoch Train Error 2.179%
# 2720th Epoch Test Error 13.770%
#
# 2730th Epoch Train Loss 0.00478
# 2730th Epoch Train Error 2.237%
# 2730th Epoch Test Error 15.048%
#
# 2740th Epoch Train Loss 0.00474
# 2740th Epoch Train Error 2.874%
# 2740th Epoch Test Error 14.232%
#
# 2750th Epoch Train Loss 0.00361
# 2750th Epoch Train Error 2.165%
# 2750th Epoch Test Error 14.134%
#
# 2760th Epoch Train Loss 0.00399
# 2760th Epoch Train Error 2.752%
# 2760th Epoch Test Error 13.939%
#
# 2770th Epoch Train Loss 0.00800
# 2770th Epoch Train Error 4.770%
# 2770th Epoch Test Error 16.404%
#
# 2780th Epoch Train Loss 0.00360
# 2780th Epoch Train Error 2.331%
# 2780th Epoch Test Error 14.058%
#
# 2790th Epoch Train Loss 0.00555
# 2790th Epoch Train Error 3.747%
# 2790th Epoch Test Error 15.257%
#
# 2800th Epoch Train Loss 0.00384
# 2800th Epoch Train Error 2.022%
# 2800th Epoch Test Error 14.105%
#
# 2810th Epoch Train Loss 0.00406
# 2810th Epoch Train Error 2.569%
# 2810th Epoch Test Error 13.074%
#
# 2820th Epoch Train Loss 0.00403
# 2820th Epoch Train Error 2.732%
# 2820th Epoch Test Error 13.151%
#
# 2830th Epoch Train Loss 0.00352
# 2830th Epoch Train Error 2.196%
# 2830th Epoch Test Error 12.993%
#
# 2840th Epoch Train Loss 0.00617
# 2840th Epoch Train Error 4.133%
# 2840th Epoch Test Error 14.101%
#
# 2850th Epoch Train Loss 0.00343
# 2850th Epoch Train Error 2.212%
# 2850th Epoch Test Error 13.043%
#
# 2860th Epoch Train Loss 0.00605
# 2860th Epoch Train Error 4.009%
# 2860th Epoch Test Error 14.089%
#
# 2870th Epoch Train Loss 0.00407
# 2870th Epoch Train Error 2.255%
# 2870th Epoch Test Error 13.009%
#
# 2880th Epoch Train Loss 0.00312
# 2880th Epoch Train Error 1.981%
# 2880th Epoch Test Error 12.651%
#
# 2890th Epoch Train Loss 0.00456
# 2890th Epoch Train Error 3.228%
# 2890th Epoch Test Error 13.590%
#
# 2900th Epoch Train Loss 0.00395
# 2900th Epoch Train Error 2.680%
# 2900th Epoch Test Error 12.752%
#
# 2910th Epoch Train Loss 0.00318
# 2910th Epoch Train Error 1.965%
# 2910th Epoch Test Error 12.746%
#
# 2920th Epoch Train Loss 0.01030
# 2920th Epoch Train Error 6.025%
# 2920th Epoch Test Error 16.310%
#
# 2930th Epoch Train Loss 0.00823
# 2930th Epoch Train Error 4.693%
# 2930th Epoch Test Error 14.134%
#
# 2940th Epoch Train Loss 0.00303
# 2940th Epoch Train Error 2.151%
# 2940th Epoch Test Error 12.815%
#
# 2950th Epoch Train Loss 0.00419
# 2950th Epoch Train Error 2.329%
# 2950th Epoch Test Error 12.484%
#
# 2960th Epoch Train Loss 0.00315
# 2960th Epoch Train Error 1.968%
# 2960th Epoch Test Error 12.612%
#
# 2970th Epoch Train Loss 0.00306
# 2970th Epoch Train Error 2.016%
# 2970th Epoch Test Error 11.940%
#
# 2980th Epoch Train Loss 0.00347
# 2980th Epoch Train Error 2.206%
# 2980th Epoch Test Error 12.494%
#
# 2990th Epoch Train Loss 0.00425
# 2990th Epoch Train Error 3.011%
# 2990th Epoch Test Error 11.686%
#
# 3000th Epoch Train Loss 0.00520
# 3000th Epoch Train Error 3.706%
# 3000th Epoch Test Error 12.387%
#
# 3010th Epoch Train Loss 0.00364
# 3010th Epoch Train Error 2.622%
# 3010th Epoch Test Error 12.249%
#
# 3020th Epoch Train Loss 0.00339
# 3020th Epoch Train Error 2.417%
# 3020th Epoch Test Error 11.449%
#
# 3030th Epoch Train Loss 0.00346
# 3030th Epoch Train Error 2.079%
# 3030th Epoch Test Error 12.578%
#
# 3040th Epoch Train Loss 0.00382
# 3040th Epoch Train Error 2.077%
# 3040th Epoch Test Error 12.491%
#
# 3050th Epoch Train Loss 0.00326
# 3050th Epoch Train Error 2.056%
# 3050th Epoch Test Error 12.858%
#
# 3060th Epoch Train Loss 0.00281
# 3060th Epoch Train Error 1.921%
# 3060th Epoch Test Error 11.155%
#
# 3070th Epoch Train Loss 0.00285
# 3070th Epoch Train Error 1.982%
# 3070th Epoch Test Error 10.828%
#
# 3080th Epoch Train Loss 0.00277
# 3080th Epoch Train Error 1.950%
# 3080th Epoch Test Error 11.014%
#
# 3090th Epoch Train Loss 0.00288
# 3090th Epoch Train Error 2.034%
# 3090th Epoch Test Error 11.619%
#
# 3100th Epoch Train Loss 0.00333
# 3100th Epoch Train Error 2.585%
# 3100th Epoch Test Error 11.183%
#
# 3110th Epoch Train Loss 0.00296
# 3110th Epoch Train Error 1.923%
# 3110th Epoch Test Error 11.109%
#
# 3120th Epoch Train Loss 0.00272
# 3120th Epoch Train Error 1.940%
# 3120th Epoch Test Error 11.148%
#
# 3130th Epoch Train Loss 0.00341
# 3130th Epoch Train Error 2.492%
# 3130th Epoch Test Error 11.856%
#
# 3140th Epoch Train Loss 0.00258
# 3140th Epoch Train Error 2.038%
# 3140th Epoch Test Error 10.576%
#
# 3150th Epoch Train Loss 0.00320
# 3150th Epoch Train Error 2.535%
# 3150th Epoch Test Error 10.319%
#
# 3160th Epoch Train Loss 0.00316
# 3160th Epoch Train Error 2.206%
# 3160th Epoch Test Error 10.690%
#
# 3170th Epoch Train Loss 0.00301
# 3170th Epoch Train Error 2.435%
# 3170th Epoch Test Error 11.294%
#
# 3180th Epoch Train Loss 0.01532
# 3180th Epoch Train Error 7.525%
# 3180th Epoch Test Error 17.965%
#
# 3190th Epoch Train Loss 0.00720
# 3190th Epoch Train Error 4.656%
# 3190th Epoch Test Error 11.922%
#
# 3200th Epoch Train Loss 0.00507
# 3200th Epoch Train Error 3.613%
# 3200th Epoch Test Error 10.965%
#
# 3210th Epoch Train Loss 0.00297
# 3210th Epoch Train Error 2.055%
# 3210th Epoch Test Error 11.068%
#
# 3220th Epoch Train Loss 0.00249
# 3220th Epoch Train Error 1.838%
# 3220th Epoch Test Error 10.781%
#
# 3230th Epoch Train Loss 0.00247
# 3230th Epoch Train Error 1.851%
# 3230th Epoch Test Error 10.559%
#
# 3240th Epoch Train Loss 0.00272
# 3240th Epoch Train Error 1.966%
# 3240th Epoch Test Error 10.496%
#
# 3250th Epoch Train Loss 0.00271
# 3250th Epoch Train Error 1.827%
# 3250th Epoch Test Error 10.054%
#
# 3260th Epoch Train Loss 0.00213
# 3260th Epoch Train Error 1.830%
# 3260th Epoch Test Error 10.066%
#
# 3270th Epoch Train Loss 0.00242
# 3270th Epoch Train Error 1.937%
# 3270th Epoch Test Error 9.624%
#
# 3280th Epoch Train Loss 0.00224
# 3280th Epoch Train Error 1.832%
# 3280th Epoch Test Error 9.797%
#
# 3290th Epoch Train Loss 0.00257
# 3290th Epoch Train Error 1.870%
# 3290th Epoch Test Error 10.210%
#
# 3300th Epoch Train Loss 0.00329
# 3300th Epoch Train Error 2.095%
# 3300th Epoch Test Error 10.228%
#
# 3310th Epoch Train Loss 0.00253
# 3310th Epoch Train Error 1.940%
# 3310th Epoch Test Error 10.513%
#
# 3320th Epoch Train Loss 0.00271
# 3320th Epoch Train Error 1.797%
# 3320th Epoch Test Error 9.815%
#
# 3330th Epoch Train Loss 0.00260
# 3330th Epoch Train Error 2.272%
# 3330th Epoch Test Error 10.276%
#
# 3340th Epoch Train Loss 0.00483
# 3340th Epoch Train Error 3.679%
# 3340th Epoch Test Error 10.330%
#
# 3350th Epoch Train Loss 0.00296
# 3350th Epoch Train Error 2.139%
# 3350th Epoch Test Error 10.738%
#
# 3360th Epoch Train Loss 0.00383
# 3360th Epoch Train Error 3.033%
# 3360th Epoch Test Error 10.375%
#
# 3370th Epoch Train Loss 0.00213
# 3370th Epoch Train Error 1.808%
# 3370th Epoch Test Error 9.333%
#
# 3380th Epoch Train Loss 0.00244
# 3380th Epoch Train Error 2.014%
# 3380th Epoch Test Error 9.584%
#
# 3390th Epoch Train Loss 0.00263
# 3390th Epoch Train Error 1.942%
# 3390th Epoch Test Error 9.058%
#
# 3400th Epoch Train Loss 0.00216
# 3400th Epoch Train Error 1.863%
# 3400th Epoch Test Error 9.320%
#
# 3410th Epoch Train Loss 0.00241
# 3410th Epoch Train Error 2.076%
# 3410th Epoch Test Error 9.437%
#
# 3420th Epoch Train Loss 0.00227
# 3420th Epoch Train Error 2.138%
# 3420th Epoch Test Error 9.348%
#
# 3430th Epoch Train Loss 0.00217
# 3430th Epoch Train Error 1.930%
# 3430th Epoch Test Error 8.900%
#
# 3440th Epoch Train Loss 0.00280
# 3440th Epoch Train Error 2.175%
# 3440th Epoch Test Error 10.104%
#
# 3450th Epoch Train Loss 0.00745
# 3450th Epoch Train Error 5.157%
# 3450th Epoch Test Error 11.676%
#
# 3460th Epoch Train Loss 0.00417
# 3460th Epoch Train Error 2.863%
# 3460th Epoch Test Error 10.131%
#
# 3470th Epoch Train Loss 0.00515
# 3470th Epoch Train Error 3.598%
# 3470th Epoch Test Error 11.225%
#
# 3480th Epoch Train Loss 0.00350
# 3480th Epoch Train Error 3.284%
# 3480th Epoch Test Error 8.575%
#
# 3490th Epoch Train Loss 0.00194
# 3490th Epoch Train Error 1.779%
# 3490th Epoch Test Error 8.821%
#
# 3500th Epoch Train Loss 0.00232
# 3500th Epoch Train Error 2.012%
# 3500th Epoch Test Error 8.209%
#
# 3510th Epoch Train Loss 0.00195
# 3510th Epoch Train Error 2.130%
# 3510th Epoch Test Error 8.211%
#
# 3520th Epoch Train Loss 0.00402
# 3520th Epoch Train Error 3.339%
# 3520th Epoch Test Error 9.405%
#
# 3530th Epoch Train Loss 0.00425
# 3530th Epoch Train Error 3.134%
# 3530th Epoch Test Error 9.586%
#
# 3540th Epoch Train Loss 0.00242
# 3540th Epoch Train Error 2.069%
# 3540th Epoch Test Error 9.348%
#
# 3550th Epoch Train Loss 0.00188
# 3550th Epoch Train Error 1.821%
# 3550th Epoch Test Error 8.226%
#
# 3560th Epoch Train Loss 0.00320
# 3560th Epoch Train Error 3.250%
# 3560th Epoch Test Error 7.878%
#
# 3570th Epoch Train Loss 0.00190
# 3570th Epoch Train Error 1.760%
# 3570th Epoch Test Error 8.238%
#
# 3580th Epoch Train Loss 0.00247
# 3580th Epoch Train Error 2.476%
# 3580th Epoch Test Error 8.507%
#
# 3590th Epoch Train Loss 0.00366
# 3590th Epoch Train Error 3.247%
# 3590th Epoch Test Error 8.642%
#
# 3600th Epoch Train Loss 0.00246
# 3600th Epoch Train Error 2.261%
# 3600th Epoch Test Error 8.308%
#
# 3610th Epoch Train Loss 0.00179
# 3610th Epoch Train Error 1.796%
# 3610th Epoch Test Error 8.452%
#
# 3620th Epoch Train Loss 0.00314
# 3620th Epoch Train Error 2.466%
# 3620th Epoch Test Error 9.537%
#
# 3630th Epoch Train Loss 0.00424
# 3630th Epoch Train Error 3.056%
# 3630th Epoch Test Error 10.163%
#
# 3640th Epoch Train Loss 0.00202
# 3640th Epoch Train Error 1.817%
# 3640th Epoch Test Error 7.567%
#
# 3650th Epoch Train Loss 0.00164
# 3650th Epoch Train Error 1.808%
# 3650th Epoch Test Error 7.660%
#
# 3660th Epoch Train Loss 0.00296
# 3660th Epoch Train Error 2.625%
# 3660th Epoch Test Error 8.643%
#
# 3670th Epoch Train Loss 0.00160
# 3670th Epoch Train Error 1.786%
# 3670th Epoch Test Error 7.898%
#
# 3680th Epoch Train Loss 0.00325
# 3680th Epoch Train Error 3.082%
# 3680th Epoch Test Error 8.969%
#
# 3690th Epoch Train Loss 0.00505
# 3690th Epoch Train Error 3.686%
# 3690th Epoch Test Error 9.309%
#
# 3700th Epoch Train Loss 0.00319
# 3700th Epoch Train Error 2.923%
# 3700th Epoch Test Error 8.945%
#
# 3710th Epoch Train Loss 0.00183
# 3710th Epoch Train Error 2.112%
# 3710th Epoch Test Error 7.325%
#
# 3720th Epoch Train Loss 0.00147
# 3720th Epoch Train Error 1.702%
# 3720th Epoch Test Error 7.179%
#
# 3730th Epoch Train Loss 0.00145
# 3730th Epoch Train Error 1.772%
# 3730th Epoch Test Error 6.951%
#
# 3740th Epoch Train Loss 0.00163
# 3740th Epoch Train Error 1.791%
# 3740th Epoch Test Error 6.711%
#
# 3750th Epoch Train Loss 0.00638
# 3750th Epoch Train Error 4.209%
# 3750th Epoch Test Error 13.033%
#
# 3760th Epoch Train Loss 0.00286
# 3760th Epoch Train Error 2.792%
# 3760th Epoch Test Error 10.121%
#
# 3770th Epoch Train Loss 0.00182
# 3770th Epoch Train Error 2.071%
# 3770th Epoch Test Error 8.716%
#
# 3780th Epoch Train Loss 0.00150
# 3780th Epoch Train Error 1.740%
# 3780th Epoch Test Error 6.763%
#
# 3790th Epoch Train Loss 0.00146
# 3790th Epoch Train Error 1.737%
# 3790th Epoch Test Error 6.607%
#
# 3800th Epoch Train Loss 0.00149
# 3800th Epoch Train Error 1.688%
# 3800th Epoch Test Error 6.622%
#
# 3810th Epoch Train Loss 0.00135
# 3810th Epoch Train Error 1.685%
# 3810th Epoch Test Error 6.531%
#
# 3820th Epoch Train Loss 0.00126
# 3820th Epoch Train Error 1.743%
# 3820th Epoch Test Error 6.341%
#
# 3830th Epoch Train Loss 0.00176
# 3830th Epoch Train Error 2.008%
# 3830th Epoch Test Error 6.538%
#
# 3840th Epoch Train Loss 0.00151
# 3840th Epoch Train Error 1.699%
# 3840th Epoch Test Error 6.347%
#
# 3850th Epoch Train Loss 0.00145
# 3850th Epoch Train Error 1.676%
# 3850th Epoch Test Error 6.646%
#
# 3860th Epoch Train Loss 0.00157
# 3860th Epoch Train Error 2.009%
# 3860th Epoch Test Error 6.259%
#
# 3870th Epoch Train Loss 0.00226
# 3870th Epoch Train Error 2.562%
# 3870th Epoch Test Error 7.099%
#
# 3880th Epoch Train Loss 0.00179
# 3880th Epoch Train Error 2.436%
# 3880th Epoch Test Error 5.845%
#
# 3890th Epoch Train Loss 0.00208
# 3890th Epoch Train Error 2.383%
# 3890th Epoch Test Error 6.779%
#
# 3900th Epoch Train Loss 0.00123
# 3900th Epoch Train Error 1.730%
# 3900th Epoch Test Error 6.384%
#
# 3910th Epoch Train Loss 0.00122
# 3910th Epoch Train Error 1.842%
# 3910th Epoch Test Error 5.566%
#
# 3920th Epoch Train Loss 0.00203
# 3920th Epoch Train Error 2.515%
# 3920th Epoch Test Error 6.678%
#
# 3930th Epoch Train Loss 0.00550
# 3930th Epoch Train Error 4.801%
# 3930th Epoch Test Error 9.158%
#
# 3940th Epoch Train Loss 0.00110
# 3940th Epoch Train Error 1.701%
# 3940th Epoch Test Error 5.931%
#
# 3950th Epoch Train Loss 0.00141
# 3950th Epoch Train Error 1.691%
# 3950th Epoch Test Error 6.351%
#
# 3960th Epoch Train Loss 0.00134
# 3960th Epoch Train Error 1.929%
# 3960th Epoch Test Error 5.587%
#
# 3970th Epoch Train Loss 0.00144
# 3970th Epoch Train Error 1.960%
# 3970th Epoch Test Error 5.496%
#
# 3980th Epoch Train Loss 0.00137
# 3980th Epoch Train Error 1.987%
# 3980th Epoch Test Error 5.593%
#
# 3990th Epoch Train Loss 0.00174
# 3990th Epoch Train Error 2.158%
# 3990th Epoch Test Error 6.282%
#
# 4000th Epoch Train Loss 0.01826
# 4000th Epoch Train Error 8.561%
# 4000th Epoch Test Error 9.508%
#
# 4010th Epoch Train Loss 0.00167
# 4010th Epoch Train Error 2.253%
# 4010th Epoch Test Error 9.083%
#
# 4020th Epoch Train Loss 0.00179
# 4020th Epoch Train Error 1.877%
# 4020th Epoch Test Error 5.851%
#
# 4030th Epoch Train Loss 0.00199
# 4030th Epoch Train Error 1.895%
# 4030th Epoch Test Error 6.069%
#
# 4040th Epoch Train Loss 0.00132
# 4040th Epoch Train Error 1.755%
# 4040th Epoch Test Error 5.821%
#
# 4050th Epoch Train Loss 0.00103
# 4050th Epoch Train Error 1.639%
# 4050th Epoch Test Error 5.313%
#
# 4060th Epoch Train Loss 0.00105
# 4060th Epoch Train Error 1.657%
# 4060th Epoch Test Error 5.408%
#
# 4070th Epoch Train Loss 0.00109
# 4070th Epoch Train Error 1.664%
# 4070th Epoch Test Error 5.298%
#
# 4080th Epoch Train Loss 0.00113
# 4080th Epoch Train Error 1.666%
# 4080th Epoch Test Error 5.186%
#
# 4090th Epoch Train Loss 0.00103
# 4090th Epoch Train Error 1.658%
# 4090th Epoch Test Error 5.109%
#
# 4100th Epoch Train Loss 0.00124
# 4100th Epoch Train Error 1.727%
# 4100th Epoch Test Error 5.432%
#
# 4110th Epoch Train Loss 0.00115
# 4110th Epoch Train Error 1.796%
# 4110th Epoch Test Error 5.416%
#
# 4120th Epoch Train Loss 0.00119
# 4120th Epoch Train Error 1.647%
# 4120th Epoch Test Error 4.998%
#
# 4130th Epoch Train Loss 0.00114
# 4130th Epoch Train Error 1.703%
# 4130th Epoch Test Error 5.306%
#
# 4140th Epoch Train Loss 0.00098
# 4140th Epoch Train Error 1.664%
# 4140th Epoch Test Error 5.324%
#
# 4150th Epoch Train Loss 0.00126
# 4150th Epoch Train Error 1.654%
# 4150th Epoch Test Error 5.689%
#
# 4160th Epoch Train Loss 0.00109
# 4160th Epoch Train Error 1.770%
# 4160th Epoch Test Error 5.252%
#
# 4170th Epoch Train Loss 0.00103
# 4170th Epoch Train Error 1.783%
# 4170th Epoch Test Error 5.057%
#
# 4180th Epoch Train Loss 0.00095
# 4180th Epoch Train Error 1.655%
# 4180th Epoch Test Error 4.819%
#
# 4190th Epoch Train Loss 0.00131
# 4190th Epoch Train Error 1.694%
# 4190th Epoch Test Error 5.919%
#
# 4200th Epoch Train Loss 0.00107
# 4200th Epoch Train Error 1.695%
# 4200th Epoch Test Error 4.661%
#
# 4210th Epoch Train Loss 0.00096
# 4210th Epoch Train Error 1.649%
# 4210th Epoch Test Error 4.470%
#
# 4220th Epoch Train Loss 0.00114
# 4220th Epoch Train Error 1.676%
# 4220th Epoch Test Error 5.249%
#
# 4230th Epoch Train Loss 0.00108
# 4230th Epoch Train Error 1.856%
# 4230th Epoch Test Error 4.236%
#
# 4240th Epoch Train Loss 0.00181
# 4240th Epoch Train Error 2.014%
# 4240th Epoch Test Error 6.121%
#
# 4250th Epoch Train Loss 0.00098
# 4250th Epoch Train Error 1.737%
# 4250th Epoch Test Error 4.461%
#
# 4260th Epoch Train Loss 0.00093
# 4260th Epoch Train Error 1.661%
# 4260th Epoch Test Error 4.585%
#
# 4270th Epoch Train Loss 0.00125
# 4270th Epoch Train Error 2.098%
# 4270th Epoch Test Error 4.716%
#
# 4280th Epoch Train Loss 0.00116
# 4280th Epoch Train Error 2.005%
# 4280th Epoch Test Error 4.317%
#
# 4290th Epoch Train Loss 0.00085
# 4290th Epoch Train Error 1.676%
# 4290th Epoch Test Error 4.560%
#
# 4300th Epoch Train Loss 0.00086
# 4300th Epoch Train Error 1.667%
# 4300th Epoch Test Error 4.692%
#
# 4310th Epoch Train Loss 0.00111
# 4310th Epoch Train Error 2.007%
# 4310th Epoch Test Error 4.858%
#
# 4320th Epoch Train Loss 0.00091
# 4320th Epoch Train Error 1.743%
# 4320th Epoch Test Error 5.018%
#
# 4330th Epoch Train Loss 0.00122
# 4330th Epoch Train Error 2.149%
# 4330th Epoch Test Error 5.406%
#
# 4340th Epoch Train Loss 0.00853
# 4340th Epoch Train Error 5.447%
# 4340th Epoch Test Error 12.132%
#
# 4350th Epoch Train Loss 0.00191
# 4350th Epoch Train Error 2.764%
# 4350th Epoch Test Error 5.958%
#
# 4360th Epoch Train Loss 0.00188
# 4360th Epoch Train Error 2.614%
# 4360th Epoch Test Error 4.441%
#
# 4370th Epoch Train Loss 0.00097
# 4370th Epoch Train Error 1.913%
# 4370th Epoch Test Error 4.960%
#
# 4380th Epoch Train Loss 0.00100
# 4380th Epoch Train Error 1.949%
# 4380th Epoch Test Error 5.029%
#
# 4390th Epoch Train Loss 0.00098
# 4390th Epoch Train Error 1.746%
# 4390th Epoch Test Error 4.157%
#
# 4400th Epoch Train Loss 0.00097
# 4400th Epoch Train Error 1.671%
# 4400th Epoch Test Error 4.379%
#
# 4410th Epoch Train Loss 0.00081
# 4410th Epoch Train Error 1.745%
# 4410th Epoch Test Error 4.022%
#
# 4420th Epoch Train Loss 0.00078
# 4420th Epoch Train Error 1.652%
# 4420th Epoch Test Error 3.866%
#
# 4430th Epoch Train Loss 0.00086
# 4430th Epoch Train Error 1.639%
# 4430th Epoch Test Error 4.177%
#
# 4440th Epoch Train Loss 0.00092
# 4440th Epoch Train Error 1.687%
# 4440th Epoch Test Error 4.195%
#
# 4450th Epoch Train Loss 0.00082
# 4450th Epoch Train Error 1.758%
# 4450th Epoch Test Error 3.902%
#
# 4460th Epoch Train Loss 0.00080
# 4460th Epoch Train Error 1.693%
# 4460th Epoch Test Error 4.045%
#
# 4470th Epoch Train Loss 0.00088
# 4470th Epoch Train Error 1.830%
# 4470th Epoch Test Error 3.657%
#
# 4480th Epoch Train Loss 0.00272
# 4480th Epoch Train Error 3.267%
# 4480th Epoch Test Error 5.631%
#
# 4490th Epoch Train Loss 0.00390
# 4490th Epoch Train Error 2.104%
# 4490th Epoch Test Error 6.162%
#
# 4500th Epoch Train Loss 0.00195
# 4500th Epoch Train Error 2.225%
# 4500th Epoch Test Error 8.042%
#
# 4510th Epoch Train Loss 0.00098
# 4510th Epoch Train Error 1.909%
# 4510th Epoch Test Error 6.216%
#
# 4520th Epoch Train Loss 0.00090
# 4520th Epoch Train Error 1.861%
# 4520th Epoch Test Error 5.256%
#
# 4530th Epoch Train Loss 0.00090
# 4530th Epoch Train Error 1.732%
# 4530th Epoch Test Error 4.332%
#
# 4540th Epoch Train Loss 0.00082
# 4540th Epoch Train Error 1.776%
# 4540th Epoch Test Error 4.343%
#
# 4550th Epoch Train Loss 0.00070
# 4550th Epoch Train Error 1.634%
# 4550th Epoch Test Error 4.010%
#
# 4560th Epoch Train Loss 0.00075
# 4560th Epoch Train Error 1.665%
# 4560th Epoch Test Error 3.783%
#
# 4570th Epoch Train Loss 0.00079
# 4570th Epoch Train Error 1.729%
# 4570th Epoch Test Error 3.931%
#
# 4580th Epoch Train Loss 0.00071
# 4580th Epoch Train Error 1.651%
# 4580th Epoch Test Error 3.773%
#
# 4590th Epoch Train Loss 0.00068
# 4590th Epoch Train Error 1.647%
# 4590th Epoch Test Error 3.886%
#
# 4600th Epoch Train Loss 0.00071
# 4600th Epoch Train Error 1.637%
# 4600th Epoch Test Error 3.924%
#
# 4610th Epoch Train Loss 0.00078
# 4610th Epoch Train Error 1.742%
# 4610th Epoch Test Error 3.666%
#
# 4620th Epoch Train Loss 0.00079
# 4620th Epoch Train Error 1.784%
# 4620th Epoch Test Error 3.989%
#
# 4630th Epoch Train Loss 0.00077
# 4630th Epoch Train Error 1.784%
# 4630th Epoch Test Error 3.543%
#
# 4640th Epoch Train Loss 0.00077
# 4640th Epoch Train Error 1.698%
# 4640th Epoch Test Error 3.782%
#
# 4650th Epoch Train Loss 0.00075
# 4650th Epoch Train Error 1.780%
# 4650th Epoch Test Error 3.532%
#
# 4660th Epoch Train Loss 0.00077
# 4660th Epoch Train Error 1.798%
# 4660th Epoch Test Error 3.724%
#
# 4670th Epoch Train Loss 0.00087
# 4670th Epoch Train Error 1.790%
# 4670th Epoch Test Error 3.780%
#
# 4680th Epoch Train Loss 0.00069
# 4680th Epoch Train Error 1.666%
# 4680th Epoch Test Error 3.333%
#
# 4690th Epoch Train Loss 0.00133
# 4690th Epoch Train Error 2.329%
# 4690th Epoch Test Error 5.625%
#
# 4700th Epoch Train Loss 0.01948
# 4700th Epoch Train Error 9.140%
# 4700th Epoch Test Error 12.006%
#
# 4710th Epoch Train Loss 0.00509
# 4710th Epoch Train Error 4.252%
# 4710th Epoch Test Error 6.580%
#
# 4720th Epoch Train Loss 0.00083
# 4720th Epoch Train Error 1.770%
# 4720th Epoch Test Error 5.291%
#
# 4730th Epoch Train Loss 0.00129
# 4730th Epoch Train Error 2.132%
# 4730th Epoch Test Error 4.298%
#
# 4740th Epoch Train Loss 0.00084
# 4740th Epoch Train Error 1.740%
# 4740th Epoch Test Error 3.805%
#
# 4750th Epoch Train Loss 0.00069
# 4750th Epoch Train Error 1.662%
# 4750th Epoch Test Error 3.590%
#
# 4760th Epoch Train Loss 0.00065
# 4760th Epoch Train Error 1.659%
# 4760th Epoch Test Error 3.562%
#
# 4770th Epoch Train Loss 0.00066
# 4770th Epoch Train Error 1.661%
# 4770th Epoch Test Error 3.608%
#
# 4780th Epoch Train Loss 0.00066
# 4780th Epoch Train Error 1.649%
# 4780th Epoch Test Error 3.634%
#
# 4790th Epoch Train Loss 0.00069
# 4790th Epoch Train Error 1.677%
# 4790th Epoch Test Error 3.690%
#
# 4800th Epoch Train Loss 0.00067
# 4800th Epoch Train Error 1.644%
# 4800th Epoch Test Error 3.303%
#
# 4810th Epoch Train Loss 0.00064
# 4810th Epoch Train Error 1.679%
# 4810th Epoch Test Error 3.587%
#
# 4820th Epoch Train Loss 0.00070
# 4820th Epoch Train Error 1.655%
# 4820th Epoch Test Error 3.655%
#
# 4830th Epoch Train Loss 0.00066
# 4830th Epoch Train Error 1.664%
# 4830th Epoch Test Error 3.888%
#
# 4840th Epoch Train Loss 0.00063
# 4840th Epoch Train Error 1.671%
# 4840th Epoch Test Error 3.414%
#
# 4850th Epoch Train Loss 0.00064
# 4850th Epoch Train Error 1.661%
# 4850th Epoch Test Error 3.201%
#
# 4860th Epoch Train Loss 0.00102
# 4860th Epoch Train Error 1.704%
# 4860th Epoch Test Error 3.921%
#
# 4870th Epoch Train Loss 0.00075
# 4870th Epoch Train Error 1.791%
# 4870th Epoch Test Error 3.131%
#
# 4880th Epoch Train Loss 0.00062
# 4880th Epoch Train Error 1.667%
# 4880th Epoch Test Error 3.198%
#
# 4890th Epoch Train Loss 0.00076
# 4890th Epoch Train Error 1.838%
# 4890th Epoch Test Error 3.661%
#
# 4900th Epoch Train Loss 0.00055
# 4900th Epoch Train Error 1.638%
# 4900th Epoch Test Error 3.418%
#
# 4910th Epoch Train Loss 0.00086
# 4910th Epoch Train Error 1.977%
# 4910th Epoch Test Error 3.537%
#
# 4920th Epoch Train Loss 0.00099
# 4920th Epoch Train Error 2.107%
# 4920th Epoch Test Error 3.039%
#
# 4930th Epoch Train Loss 0.00109
# 4930th Epoch Train Error 2.181%
# 4930th Epoch Test Error 4.541%
#
# 4940th Epoch Train Loss 0.00657
# 4940th Epoch Train Error 5.581%
# 4940th Epoch Test Error 7.587%
#
# 4950th Epoch Train Loss 0.00134
# 4950th Epoch Train Error 2.020%
# 4950th Epoch Test Error 4.080%
#
# 4960th Epoch Train Loss 0.00106
# 4960th Epoch Train Error 1.717%
# 4960th Epoch Test Error 5.544%
#
# 4970th Epoch Train Loss 0.00095
# 4970th Epoch Train Error 2.143%
# 4970th Epoch Test Error 4.111%
#
# 4980th Epoch Train Loss 0.00070
# 4980th Epoch Train Error 1.734%
# 4980th Epoch Test Error 3.515%
#
# 4990th Epoch Train Loss 0.00069
# 4990th Epoch Train Error 1.650%
# 4990th Epoch Test Error 3.304%
#
# ...
# 8340th Epoch Test Error 1.972%
#
# 8350th Epoch Train Loss 0.00035
# 8350th Epoch Train Error 1.662%
# 8350th Epoch Test Error 1.731%
#
# 8360th Epoch Train Loss 0.00063
# 8360th Epoch Train Error 1.823%
# 8360th Epoch Test Error 3.074%
#
# 8370th Epoch Train Loss 0.00033
# 8370th Epoch Train Error 1.629%
# 8370th Epoch Test Error 1.753%
#
# 8380th Epoch Train Loss 0.00085
# 8380th Epoch Train Error 1.818%
# 8380th Epoch Test Error 4.592%
#
# 8390th Epoch Train Loss 0.00094
# 8390th Epoch Train Error 2.198%
# 8390th Epoch Test Error 2.753%
#
# 8400th Epoch Train Loss 0.00059
# 8400th Epoch Train Error 1.889%
# 8400th Epoch Test Error 1.944%
#
# 8410th Epoch Train Loss 0.00058
# 8410th Epoch Train Error 1.725%
# 8410th Epoch Test Error 2.589%
#
# 8420th Epoch Train Loss 0.00059
# 8420th Epoch Train Error 1.968%
# 8420th Epoch Test Error 1.941%
#
# 8430th Epoch Train Loss 0.00042
# 8430th Epoch Train Error 1.769%
# 8430th Epoch Test Error 1.853%
#
# 8440th Epoch Train Loss 0.00074
# 8440th Epoch Train Error 2.193%
# 8440th Epoch Test Error 2.320%
#
# 8450th Epoch Train Loss 0.00159
# 8450th Epoch Train Error 2.133%
# 8450th Epoch Test Error 5.935%
#
# 8460th Epoch Train Loss 0.00050
# 8460th Epoch Train Error 1.768%
# 8460th Epoch Test Error 2.082%
#
# 8470th Epoch Train Loss 0.00053
# 8470th Epoch Train Error 1.631%
# 8470th Epoch Test Error 1.882%
#
# 8480th Epoch Train Loss 0.00052
# 8480th Epoch Train Error 1.796%
# 8480th Epoch Test Error 2.018%
#
# 8490th Epoch Train Loss 0.00050
# 8490th Epoch Train Error 1.629%
# 8490th Epoch Test Error 2.746%
#
# 8500th Epoch Train Loss 0.00038
# 8500th Epoch Train Error 1.723%
# 8500th Epoch Test Error 1.848%
#
# 8510th Epoch Train Loss 0.00038
# 8510th Epoch Train Error 1.683%
# 8510th Epoch Test Error 2.032%
#
# 8520th Epoch Train Loss 0.00038
# 8520th Epoch Train Error 1.690%
# 8520th Epoch Test Error 2.216%
#
# 8530th Epoch Train Loss 0.00062
# 8530th Epoch Train Error 1.964%
# 8530th Epoch Test Error 2.433%
#
# 8540th Epoch Train Loss 0.00102
# 8540th Epoch Train Error 2.126%
# 8540th Epoch Test Error 4.285%
#
# 8550th Epoch Train Loss 0.00032
# 8550th Epoch Train Error 1.625%
# 8550th Epoch Test Error 1.846%
#
# 8560th Epoch Train Loss 0.00056
# 8560th Epoch Train Error 1.714%
# 8560th Epoch Test Error 2.358%
#
# 8570th Epoch Train Loss 0.00038
# 8570th Epoch Train Error 1.694%
# 8570th Epoch Test Error 2.018%
#
# 8580th Epoch Train Loss 0.00033
# 8580th Epoch Train Error 1.639%
# 8580th Epoch Test Error 1.747%
#
# 8590th Epoch Train Loss 0.00032
# 8590th Epoch Train Error 1.636%
# 8590th Epoch Test Error 1.723%
#
# 8600th Epoch Train Loss 0.00047
# 8600th Epoch Train Error 1.825%
# 8600th Epoch Test Error 1.832%
#
# 8610th Epoch Train Loss 0.00030
# 8610th Epoch Train Error 1.618%
# 8610th Epoch Test Error 1.722%
#
# 8620th Epoch Train Loss 0.00036
# 8620th Epoch Train Error 1.693%
# 8620th Epoch Test Error 1.819%
#
# 8630th Epoch Train Loss 0.00106
# 8630th Epoch Train Error 2.029%
# 8630th Epoch Test Error 4.373%
#
# 8640th Epoch Train Loss 0.00301
# 8640th Epoch Train Error 3.215%
# 8640th Epoch Test Error 4.051%
#
# 8650th Epoch Train Loss 0.00095
# 8650th Epoch Train Error 2.104%
# 8650th Epoch Test Error 4.253%
#
# 8660th Epoch Train Loss 0.00043
# 8660th Epoch Train Error 1.752%
# 8660th Epoch Test Error 2.285%
#
# 8670th Epoch Train Loss 0.00054
# 8670th Epoch Train Error 1.912%
# 8670th Epoch Test Error 1.874%
#
# 8680th Epoch Train Loss 0.00042
# 8680th Epoch Train Error 1.628%
# 8680th Epoch Test Error 1.967%
#
# 8690th Epoch Train Loss 0.00033
# 8690th Epoch Train Error 1.647%
# 8690th Epoch Test Error 2.097%
#
# 8700th Epoch Train Loss 0.00051
# 8700th Epoch Train Error 1.637%
# 8700th Epoch Test Error 1.997%
#
# 8710th Epoch Train Loss 0.00033
# 8710th Epoch Train Error 1.624%
# 8710th Epoch Test Error 1.996%
#
# 8720th Epoch Train Loss 0.00032
# 8720th Epoch Train Error 1.622%
# 8720th Epoch Test Error 1.832%
#
# 8730th Epoch Train Loss 0.00036
# 8730th Epoch Train Error 1.678%
# 8730th Epoch Test Error 1.764%
#
# 8740th Epoch Train Loss 0.00032
# 8740th Epoch Train Error 1.650%
# 8740th Epoch Test Error 1.723%
#
# 8750th Epoch Train Loss 0.00032
# 8750th Epoch Train Error 1.618%
# 8750th Epoch Test Error 1.938%
#
# 8760th Epoch Train Loss 0.00033
# 8760th Epoch Train Error 1.666%
# 8760th Epoch Test Error 1.732%
#
# 8770th Epoch Train Loss 0.00034
# 8770th Epoch Train Error 1.619%
# 8770th Epoch Test Error 1.945%
#
# 8780th Epoch Train Loss 0.00049
# 8780th Epoch Train Error 1.817%
# 8780th Epoch Test Error 1.865%
#
# 8790th Epoch Train Loss 0.00071
# 8790th Epoch Train Error 1.803%
# 8790th Epoch Test Error 3.492%
#
# 8800th Epoch Train Loss 0.00045
# 8800th Epoch Train Error 1.729%
# 8800th Epoch Test Error 1.801%
#
# 8810th Epoch Train Loss 0.00052
# 8810th Epoch Train Error 1.647%
# 8810th Epoch Test Error 2.823%
#
# 8820th Epoch Train Loss 0.00095
# 8820th Epoch Train Error 2.233%
# 8820th Epoch Test Error 3.223%
#
# 8830th Epoch Train Loss 0.00058
# 8830th Epoch Train Error 1.685%
# 8830th Epoch Test Error 2.098%
#
# 8840th Epoch Train Loss 0.00037
# 8840th Epoch Train Error 1.708%
# 8840th Epoch Test Error 1.907%
#
# 8850th Epoch Train Loss 0.00035
# 8850th Epoch Train Error 1.636%
# 8850th Epoch Test Error 2.069%
#
# 8860th Epoch Train Loss 0.00046
# 8860th Epoch Train Error 1.838%
# 8860th Epoch Test Error 2.073%
#
# 8870th Epoch Train Loss 0.00127
# 8870th Epoch Train Error 2.436%
# 8870th Epoch Test Error 3.982%
#
# 8880th Epoch Train Loss 0.00052
# 8880th Epoch Train Error 1.775%
# 8880th Epoch Test Error 1.863%
#
# 8890th Epoch Train Loss 0.00071
# 8890th Epoch Train Error 1.666%
# 8890th Epoch Test Error 3.086%
#
# 8900th Epoch Train Loss 0.00054
# 8900th Epoch Train Error 1.636%
# 8900th Epoch Test Error 1.931%
#
# 8910th Epoch Train Loss 0.00035
# 8910th Epoch Train Error 1.673%
# 8910th Epoch Test Error 1.825%
#
# 8920th Epoch Train Loss 0.00033
# 8920th Epoch Train Error 1.666%
# 8920th Epoch Test Error 1.796%
#
# 8930th Epoch Train Loss 0.00037
# 8930th Epoch Train Error 1.681%
# 8930th Epoch Test Error 1.914%
#
# 8940th Epoch Train Loss 0.00035
# 8940th Epoch Train Error 1.621%
# 8940th Epoch Test Error 2.426%
#
# 8950th Epoch Train Loss 0.00072
# 8950th Epoch Train Error 2.075%
# 8950th Epoch Test Error 2.702%
#
# 8960th Epoch Train Loss 0.00052
# 8960th Epoch Train Error 1.637%
# 8960th Epoch Test Error 2.620%
#
# 8970th Epoch Train Loss 0.00031
# 8970th Epoch Train Error 1.642%
# 8970th Epoch Test Error 1.699%
#
# 8980th Epoch Train Loss 0.00038
# 8980th Epoch Train Error 1.629%
# 8980th Epoch Test Error 2.608%
#
# 8990th Epoch Train Loss 0.00199
# 8990th Epoch Train Error 3.014%
# 8990th Epoch Test Error 4.481%
#
# 9000th Epoch Train Loss 0.00045
# 9000th Epoch Train Error 1.723%
# 9000th Epoch Test Error 2.148%
#
# 9010th Epoch Train Loss 0.00035
# 9010th Epoch Train Error 1.654%
# 9010th Epoch Test Error 1.896%
#
# 9020th Epoch Train Loss 0.00030
# 9020th Epoch Train Error 1.620%
# 9020th Epoch Test Error 1.635%
#
# 9030th Epoch Train Loss 0.00032
# 9030th Epoch Train Error 1.639%
# 9030th Epoch Test Error 1.731%
#
# 9040th Epoch Train Loss 0.00033
# 9040th Epoch Train Error 1.623%
# 9040th Epoch Test Error 1.757%
#
# 9050th Epoch Train Loss 0.00031
# 9050th Epoch Train Error 1.634%
# 9050th Epoch Test Error 1.701%
#
# 9060th Epoch Train Loss 0.00030
# 9060th Epoch Train Error 1.624%
# 9060th Epoch Test Error 1.608%
#
# 9070th Epoch Train Loss 0.00029
# 9070th Epoch Train Error 1.613%
# 9070th Epoch Test Error 1.550%
#
# 9080th Epoch Train Loss 0.00032
# 9080th Epoch Train Error 1.636%
# 9080th Epoch Test Error 1.628%
#
# 9090th Epoch Train Loss 0.00029
# 9090th Epoch Train Error 1.613%
# 9090th Epoch Test Error 1.558%
#
# 9100th Epoch Train Loss 0.00029
# 9100th Epoch Train Error 1.620%
# 9100th Epoch Test Error 1.564%
#
# 9110th Epoch Train Loss 0.00031
# 9110th Epoch Train Error 1.624%
# 9110th Epoch Test Error 1.556%
#
# 9120th Epoch Train Loss 0.00030
# 9120th Epoch Train Error 1.626%
# 9120th Epoch Test Error 1.543%
#
# 9130th Epoch Train Loss 0.00030
# 9130th Epoch Train Error 1.618%
# 9130th Epoch Test Error 1.576%
#
# 9140th Epoch Train Loss 0.00034
# 9140th Epoch Train Error 1.630%
# 9140th Epoch Test Error 1.672%
#
# 9150th Epoch Train Loss 0.00034
# 9150th Epoch Train Error 1.633%
# 9150th Epoch Test Error 1.651%
#
# 9160th Epoch Train Loss 0.00051
# 9160th Epoch Train Error 1.691%
# 9160th Epoch Test Error 1.942%
#
# 9170th Epoch Train Loss 0.00058
# 9170th Epoch Train Error 1.808%
# 9170th Epoch Test Error 3.184%
#
# 9180th Epoch Train Loss 0.00060
# 9180th Epoch Train Error 1.767%
# 9180th Epoch Test Error 3.199%
#
# 9190th Epoch Train Loss 0.00047
# 9190th Epoch Train Error 1.809%
# 9190th Epoch Test Error 1.887%
#
# 9200th Epoch Train Loss 0.00042
# 9200th Epoch Train Error 1.731%
# 9200th Epoch Test Error 2.061%
#
# 9210th Epoch Train Loss 0.00032
# 9210th Epoch Train Error 1.623%
# 9210th Epoch Test Error 1.528%
#
# 9220th Epoch Train Loss 0.00036
# 9220th Epoch Train Error 1.706%
# 9220th Epoch Test Error 1.700%
#
# 9230th Epoch Train Loss 0.00032
# 9230th Epoch Train Error 1.659%
# 9230th Epoch Test Error 1.493%
#
# 9240th Epoch Train Loss 0.00034
# 9240th Epoch Train Error 1.617%
# 9240th Epoch Test Error 1.856%
#
# 9250th Epoch Train Loss 0.00036
# 9250th Epoch Train Error 1.618%
# 9250th Epoch Test Error 2.069%
#
# 9260th Epoch Train Loss 0.00035
# 9260th Epoch Train Error 1.666%
# 9260th Epoch Test Error 1.714%
#
# 9270th Epoch Train Loss 0.00039
# 9270th Epoch Train Error 1.733%
# 9270th Epoch Test Error 1.623%
#
# 9280th Epoch Train Loss 0.00033
# 9280th Epoch Train Error 1.614%
# 9280th Epoch Test Error 1.806%
#
# 9290th Epoch Train Loss 0.00030
# 9290th Epoch Train Error 1.628%
# 9290th Epoch Test Error 1.511%
#
# 9300th Epoch Train Loss 0.00039
# 9300th Epoch Train Error 1.614%
# 9300th Epoch Test Error 2.146%
#
# 9310th Epoch Train Loss 0.00482
# 9310th Epoch Train Error 4.157%
# 9310th Epoch Test Error 6.793%
#
# 9320th Epoch Train Loss 0.00065
# 9320th Epoch Train Error 2.097%
# 9320th Epoch Test Error 2.171%
#
# 9330th Epoch Train Loss 0.00066
# 9330th Epoch Train Error 2.006%
# 9330th Epoch Test Error 2.256%
#
# 9340th Epoch Train Loss 0.00041
# 9340th Epoch Train Error 1.630%
# 9340th Epoch Test Error 1.973%
#
# 9350th Epoch Train Loss 0.00043
# 9350th Epoch Train Error 1.715%
# 9350th Epoch Test Error 1.717%
#
# 9360th Epoch Train Loss 0.00037
# 9360th Epoch Train Error 1.625%
# 9360th Epoch Test Error 1.843%
#
# 9370th Epoch Train Loss 0.00031
# 9370th Epoch Train Error 1.647%
# 9370th Epoch Test Error 1.639%
#
# 9380th Epoch Train Loss 0.00030
# 9380th Epoch Train Error 1.622%
# 9380th Epoch Test Error 1.536%
#
# 9390th Epoch Train Loss 0.00029
# 9390th Epoch Train Error 1.616%
# 9390th Epoch Test Error 1.526%
#
# 9400th Epoch Train Loss 0.00029
# 9400th Epoch Train Error 1.620%
# 9400th Epoch Test Error 1.554%
#
# 9410th Epoch Train Loss 0.00030
# 9410th Epoch Train Error 1.637%
# 9410th Epoch Test Error 1.534%
#
# 9420th Epoch Train Loss 0.00033
# 9420th Epoch Train Error 1.640%
# 9420th Epoch Test Error 1.502%
#
# 9430th Epoch Train Loss 0.00043
# 9430th Epoch Train Error 1.798%
# 9430th Epoch Test Error 1.750%
#
# 9440th Epoch Train Loss 0.00057
# 9440th Epoch Train Error 1.890%
# 9440th Epoch Test Error 1.914%
#
# 9450th Epoch Train Loss 0.00031
# 9450th Epoch Train Error 1.631%
# 9450th Epoch Test Error 1.490%
#
# 9460th Epoch Train Loss 0.00029
# 9460th Epoch Train Error 1.625%
# 9460th Epoch Test Error 1.628%
#
# 9470th Epoch Train Loss 0.00054
# 9470th Epoch Train Error 1.751%
# 9470th Epoch Test Error 2.325%
#
# 9480th Epoch Train Loss 0.00078
# 9480th Epoch Train Error 2.061%
# 9480th Epoch Test Error 3.004%
#
# 9490th Epoch Train Loss 0.00083
# 9490th Epoch Train Error 1.808%
# 9490th Epoch Test Error 3.497%
#
# 9500th Epoch Train Loss 0.00033
# 9500th Epoch Train Error 1.646%
# 9500th Epoch Test Error 1.526%
#
# 9510th Epoch Train Loss 0.00032
# 9510th Epoch Train Error 1.661%
# 9510th Epoch Test Error 1.531%
#
# 9520th Epoch Train Loss 0.00047
# 9520th Epoch Train Error 1.809%
# 9520th Epoch Test Error 2.105%
#
# 9530th Epoch Train Loss 0.00032
# 9530th Epoch Train Error 1.636%
# 9530th Epoch Test Error 1.616%
#
# 9540th Epoch Train Loss 0.00029
# 9540th Epoch Train Error 1.614%
# 9540th Epoch Test Error 1.549%
#
# 9550th Epoch Train Loss 0.00034
# 9550th Epoch Train Error 1.686%
# 9550th Epoch Test Error 1.568%
#
# 9560th Epoch Train Loss 0.00029
# 9560th Epoch Train Error 1.623%
# 9560th Epoch Test Error 1.478%
#
# 9570th Epoch Train Loss 0.00051
# 9570th Epoch Train Error 1.844%
# 9570th Epoch Test Error 2.512%
#
# 9580th Epoch Train Loss 0.00410
# 9580th Epoch Train Error 3.330%
# 9580th Epoch Test Error 4.157%
#
# 9590th Epoch Train Loss 0.00127
# 9590th Epoch Train Error 1.772%
# 9590th Epoch Test Error 5.610%
#
# 9600th Epoch Train Loss 0.00089
# 9600th Epoch Train Error 1.676%
# 9600th Epoch Test Error 3.865%
#
# 9610th Epoch Train Loss 0.00076
# 9610th Epoch Train Error 1.870%
# 9610th Epoch Test Error 2.881%
#
# 9620th Epoch Train Loss 0.00048
# 9620th Epoch Train Error 1.737%
# 9620th Epoch Test Error 2.188%
#
# 9630th Epoch Train Loss 0.00031
# 9630th Epoch Train Error 1.634%
# 9630th Epoch Test Error 1.665%
#
# 9640th Epoch Train Loss 0.00029
# 9640th Epoch Train Error 1.611%
# 9640th Epoch Test Error 1.616%
#
# 9650th Epoch Train Loss 0.00028
# 9650th Epoch Train Error 1.613%
# 9650th Epoch Test Error 1.490%
#
# 9660th Epoch Train Loss 0.00028
# 9660th Epoch Train Error 1.612%
# 9660th Epoch Test Error 1.489%
#
# 9670th Epoch Train Loss 0.00031
# 9670th Epoch Train Error 1.617%
# 9670th Epoch Test Error 1.579%
#
# 9680th Epoch Train Loss 0.00029
# 9680th Epoch Train Error 1.618%
# 9680th Epoch Test Error 1.493%
#
# 9690th Epoch Train Loss 0.00030
# 9690th Epoch Train Error 1.621%
# 9690th Epoch Test Error 1.563%
#
# 9700th Epoch Train Loss 0.00028
# 9700th Epoch Train Error 1.612%
# 9700th Epoch Test Error 1.469%
#
# 9710th Epoch Train Loss 0.00031
# 9710th Epoch Train Error 1.615%
# 9710th Epoch Test Error 1.538%
#
# 9720th Epoch Train Loss 0.00028
# 9720th Epoch Train Error 1.622%
# 9720th Epoch Test Error 1.502%
#
# 9730th Epoch Train Loss 0.00029
# 9730th Epoch Train Error 1.628%
# 9730th Epoch Test Error 1.405%
#
# 9740th Epoch Train Loss 0.00044
# 9740th Epoch Train Error 1.635%
# 9740th Epoch Test Error 2.766%
#
# 9750th Epoch Train Loss 0.00033
# 9750th Epoch Train Error 1.644%
# 9750th Epoch Test Error 1.419%
#
# 9760th Epoch Train Loss 0.00031
# 9760th Epoch Train Error 1.618%
# 9760th Epoch Test Error 1.474%
#
# 9770th Epoch Train Loss 0.00052
# 9770th Epoch Train Error 1.798%
# 9770th Epoch Test Error 2.714%
#
# 9780th Epoch Train Loss 0.00111
# 9780th Epoch Train Error 2.487%
# 9780th Epoch Test Error 2.278%
#
# 9790th Epoch Train Loss 0.00036
# 9790th Epoch Train Error 1.664%
# 9790th Epoch Test Error 1.596%
#
# 9800th Epoch Train Loss 0.00064
# 9800th Epoch Train Error 2.096%
# 9800th Epoch Test Error 2.392%
#
# 9810th Epoch Train Loss 0.00033
# 9810th Epoch Train Error 1.668%
# 9810th Epoch Test Error 1.446%
#
# 9820th Epoch Train Loss 0.00049
# 9820th Epoch Train Error 1.687%
# 9820th Epoch Test Error 2.176%
#
# 9830th Epoch Train Loss 0.00034
# 9830th Epoch Train Error 1.660%
# 9830th Epoch Test Error 1.681%
#
# 9840th Epoch Train Loss 0.00028
# 9840th Epoch Train Error 1.620%
# 9840th Epoch Test Error 1.545%
#
# 9850th Epoch Train Loss 0.00070
# 9850th Epoch Train Error 1.891%
# 9850th Epoch Test Error 3.207%
#
# 9860th Epoch Train Loss 0.00062
# 9860th Epoch Train Error 1.923%
# 9860th Epoch Test Error 2.592%
#
# 9870th Epoch Train Loss 0.00052
# 9870th Epoch Train Error 1.707%
# 9870th Epoch Test Error 2.149%
#
# 9880th Epoch Train Loss 0.00037
# 9880th Epoch Train Error 1.657%
# 9880th Epoch Test Error 1.771%
#
# 9890th Epoch Train Loss 0.00051
# 9890th Epoch Train Error 1.777%
# 9890th Epoch Test Error 2.107%
#
# 9900th Epoch Train Loss 0.00062
# 9900th Epoch Train Error 1.771%
# 9900th Epoch Test Error 2.686%
#
# 9910th Epoch Train Loss 0.00037
# 9910th Epoch Train Error 1.665%
# 9910th Epoch Test Error 1.834%
#
# 9920th Epoch Train Loss 0.00034
# 9920th Epoch Train Error 1.686%
# 9920th Epoch Test Error 1.664%
#
# 9930th Epoch Train Loss 0.00035
# 9930th Epoch Train Error 1.615%
# 9930th Epoch Test Error 1.979%
#
# 9940th Epoch Train Loss 0.00049
# 9940th Epoch Train Error 1.861%
# 9940th Epoch Test Error 2.085%
#
# 9950th Epoch Train Loss 0.00041
# 9950th Epoch Train Error 1.788%
# 9950th Epoch Test Error 1.605%
#
# 9960th Epoch Train Loss 0.00041
# 9960th Epoch Train Error 1.736%
# 9960th Epoch Test Error 1.755%
#
# 9970th Epoch Train Loss 0.00083
# 9970th Epoch Train Error 2.177%
# 9970th Epoch Test Error 2.935%
#
# 9980th Epoch Train Loss 0.00083
# 9980th Epoch Train Error 1.903%
# 9980th Epoch Test Error 2.293%
#
# 9990th Epoch Train Loss 0.00045
# 9990th Epoch Train Error 1.839%
# 9990th Epoch Test Error 1.848%
#
# 10000th Epoch Train Loss 0.00030
# 10000th Epoch Train Error 1.644%
# 10000th Epoch Test Error 1.568%

# %%
torch.save(model.state_dict(), '1D_wave_eqn.pth')
from google.colab import files

files.download('1D_wave_eqn.pth')
